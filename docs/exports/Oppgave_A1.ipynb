# %% [markdown]
# # Øving A1: Symmetrisk skade
# **Gitt**- L = 50.0 m
# - B = 10.0 m
# - D = 5.0 m
# - T = 2.80 m
# - l_d = 2.0 m
#
#
# **Oppgave**
# - Beregn ny likevektsdypgang ved symmetrisk fylling.

# %%
L = 50.0
B = 10.0
D = 5.0
T = 2.80
l_d = 2.0
T_S = None

# %% [markdown]
# **Besvarelse**
# - Endelig dypgang $T_S$

# %% [markdown]
# ## Fasit$T_S = 2.9167\ \mathrm{m}$
