# %% [markdown]
# # Øving A2: Tre avdelinger
# **Gitt**- L = 60.0 m
# - B = 12.0 m
# - D = 6.0 m
# - T = 3.00 m
# - N = 3
#
#
# **Oppgave**
# - En lekter er delt inn i 3 like store avdelinger langskips. Den midtre avdelingen er skadet.

# %%
L = 60.0
B = 12.0
D = 6.0
T = 3.00
N = 3
l_d = None
T_S = None

# %% [markdown]
# **Besvarelse**
# - Skadelengde $l_d$
# - Symmetrisk skadet dypgang $T_S$
# - Sjekk om $T_S < D$

# %% [markdown]
# ## Fasit$l_d = 20.0\ \mathrm{m}$
# $T_S = 4.50\ \mathrm{m}$
