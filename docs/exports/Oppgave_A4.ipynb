# %% [markdown]
# # Øving A4: Stabilitet etter skade
# **Gitt**- KB_S = 1.62 m
# - I_WL_S = 7600 m^4
# - nabla = 2160 m^3
# - KG = 4.20 m
#
#
# **Oppgave**
# - Beregn oppdatert $KB_S$, $BM_{T_S}$ og $GM_S$ i skadet tilstand.

# %%
KB_S = 1.62
I_WL_S = 7600.0
nabla = 2160.0
KG = 4.20
BM_T_S = None
GM_S = None

# %% [markdown]
# **Leveranse**
# - Oppdaterte hydrostatiske data etter skade
# - Kort stabilitetstolkning

# %% [markdown]
# ## Fasit$BM_{T_S} = 3.519\ \mathrm{m}$
# $GM_S = 0.939\ \mathrm{m}$
