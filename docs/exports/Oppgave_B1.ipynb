# %% [markdown]
# # Øving B1: Sensitivitetsstudie
# **Gitt**- KG = 4.20 m
# - rho = 1.0 t/m^3
#
#
# **Oppgave**
# - For hvert tilfelle: beregn $l_d=L/N$, $T_S$, $BM_{T_S}$ og $GM_S$.
# - Sammenlign hvordan endringene i inndata påvirker $T_S$ og $GM_S$.

# %%
cases = [
    {'name': 'Basis', 'L': 60.0, 'B': 12.0, 'T': 3.00, 'N': 5},
    {'name': 'Færre avdelinger', 'L': 60.0, 'B': 12.0, 'T': 3.00, 'N': 3},
    {'name': 'Bredere lekter', 'L': 60.0, 'B': 14.0, 'T': 3.00, 'N': 5},
    {'name': 'Stor initial dypgang', 'L': 60.0, 'B': 12.0, 'T': 3.50, 'N': 5}
 ]
KG = 4.20
rho = 1.0
results = None

# %% [markdown]
# **Leveranse**
# - Utfylt tabell
# - Kort trenddiskusjon

# %% [markdown]
# ## Fasit| Tilfelle | l_d (m) | T_S (m) | BM_{T_S} (m) | GM_S (m) |
# |---|---:|---:|---:|---:|
# | Basis | 12.0 | 3.750 | 3.200 | 0.875 |
# | Færre avdelinger | 20.0 | 4.500 | 2.667 | 0.717 |
# | Bredere lekter | 12.0 | 3.750 | 4.356 | 2.031 |
# | Stor initial dypgang | 12.0 | 4.375 | 2.743 | 0.730 |
