# %% [markdown]
# # Øving C1: Trimmoment
#
# **Gitt**
# - L = 100.0 m
# - B = 20.0 m
# - T = 3.50 m
# - $ \rho $ = 1.025 t/m^3
# - $ LCG $ = 50.0 m
# - $ LCB_S $ = 45.0 m
#
#
# **Oppgave**
# - Bestem trimmomentet som oppstår når avdeling 4 (regnet fra AP) er skadet.

# %%
L = 100.0
B = 20.0
T = 3.50
rho = 1.025
LCG = 50.0
LCB_S = 45.0
nabla = None
Delta = None
l_k = None
M_T = None

# %% [markdown]
# **Leveranse**
# - Vektdeplasement $\Delta$
# - Trimarm $l_k = LCG - LCB_S$
# - Trimmoment $M_{trim} = \Delta\,l_k$

# %% [markdown]
# ## Fasit
# $\Delta = 7175\ \mathrm{t}$
# $l_k = 5.0\ \mathrm{m}$
# $M_T = 35{,}875\ \mathrm{t\cdot m}$
