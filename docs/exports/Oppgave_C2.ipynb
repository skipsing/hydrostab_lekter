# %% [markdown]
# # Øving C2: Trim fra gitt moment
#
# **Gitt**
# - $ \Delta = 7175 \text{ t} $
# - $ L = 100.0 \text{ m} $
# - $ BM_{L_S} = 207.619 \text{ m} $
# - $ M_T = 35 875 \text{ t m} $
#
#
# **Oppgave**
# - Beregn enhetstrimmomentet $MCT_{1cm_S}$ og total trim.

# %%
Delta = 7175.0
L = 100.0
BM_L_S = 207.619
M_T = 35875.0
MCT_1cm_S = None
t_cm = None
t_m = None

# %% [markdown]
# **Leveranse**
# - Enhetstrimmomentet $MCT_{1cm_S}$ i $\mathrm{t\,m/cm}$
# - Den totale trimmen $t$

# %% [markdown]
# ## Fasit
# $MCT_{1cm_S} = 148.967\ \mathrm{t\cdot m/cm}$
# $t = 240.83\ \mathrm{cm}$
# $t_m = 2.4083\ \mathrm{m}$
