# %% [markdown]
# # Øving C3: Fordeling av trim
#
# **Gitt**
# - $ t_m = 2.4083 \text{ m} $
# - $ LCF_S = 45.0 \text{ m} $
# - $ L = 100.0 \text{ m} $
# - $ T_S = 4.375 \text{ m} $
#
#
# **Oppgave**
# - Fordel kjent trim i akterlig og forlig komponent og beregn endelige dypganger.

# %%
t_m = 2.4083
LCF_S = 45.0
L = 100.0
T_S = 4.375
t_a = None
t_f = None
T_A = None
T_F = None
T_crit = None

# %% [markdown]
# **Leveranse**
# - $t_a$ og $t_f$
# - Endelige dypganger $T_A$ og $T_F$

# %% [markdown]
# ## Fasit
# $t_a = 1.084\ \mathrm{m}$
# $t_f = 1.3246\ \mathrm{m}$
# $T_A = 3.291\ \mathrm{m}$
# $T_F = 5.700\ \mathrm{m}$
# $T_{crit} = 5.700\ \mathrm{m}$
