# %% [markdown]
# # Øving D1: Full beregning
# **Gitt**- L = 60.0 m
# - B = 12.0 m
# - D = 6.0 m
# - T = 3.00 m
# - KG = 4.20 m
# - l_d = 3.5 m
# - KB_S = 1.62 m
# - I_WL_S = 7600 m^4
# - I_F_S = 2.10e6 m^4
# - LCB_S = 29.75 m
# - LCF_S = 30.00 m
# - LCG = 30.00 m
#
#
# **Oppgave**
# - Beregn skadet likevekt fra initial tilstand til endelig akseptkontroll.

# %%
L = 60.0
B = 12.0
D = 6.0
T = 3.00
KG = 4.20
l_d = 3.5
KB_S = 1.62
I_WL_S = 7600.0
I_F_S = 2.10e6
LCB_S = 29.75
LCF_S = 30.00
LCG = 30.00
rho = 1.0
T_S = None
T_A = None
T_F = None
GM_S = None

# %% [markdown]
# **Leveranse**
# - Endelige dypganger $T_A$ og $T_F$
# - Akseptkontroller: $GM_S > 0\ \mathrm{m}$ og $\max(T_A, T_F) < D$

# %% [markdown]
# ## Fasit$T_S = 3.1858\ \mathrm{m}$
# $T_A = 3.1781\ \mathrm{m}$
# $T_F = 3.1935\ \mathrm{m}$
# $GM_S = 0.939\ \mathrm{m}$
# PASS
