# %% [markdown]
# # Obligatorisk oppgave: Avdeling 2 skadet
#
# ## Oppgave
# En rektangulær lekter har 5 like store vanntette avdelinger langskips. Avdeling 2 (regnet fra AP) er fullstendig skadet.
#
# Beregn ny likevekt og endelige dypganger. Verifiser at trimmen er mot klokka og at $T_A > T_F$.
#
# ## Gitt
# - $L = 80.0\ \mathrm{m}$
# - $B = 18.0\ \mathrm{m}$
# - $D = 10.0\ \mathrm{m}$
# - Initial dypgang: $T = 3.20\ \mathrm{m}$
# - $KG = 3.80\ \mathrm{m}$
# - Sjoevannstetthet: $\rho = 1.025\ \mathrm{t/m^3}$
# - $LCG = 40.0\ \mathrm{m}$ fra AP (midskips)
# - 5 like store avdelinger, slik at hver avdeling har lengde $L/5=16.0\ \mathrm{m}$
# - Skadet avdeling: nr. 2 fra AP, fra $x=16$ til $x=32\ \mathrm{m}$
#
# ## Leveranse
# 1. Initialt deplasementsvolum $\nabla$ og vektdeplasement $\Delta$
# 2. Symmetrisk skadet dypgang $T_S$ fra tapt oppdriftsgivende lengde
# 3. Oppdatert hydrostatikk i skadet tilstand: $LCB_S$, $LCF_S$, $I_{WL_S}$, $I_{F_S}$
# 4. Oppdatert metasenterradiuser og metasenterhøyde: $BM_{T_S}$, $BM_{L_S}$, $GM_S$
# 5. Trimmoment $M_T$ og total trim $t$
# 6. Trimkomponenter $t_a$ og $t_f$ (i cm), samt endelige dypganger $T_A$, $T_F$
# 7. Akseptkontroller: $GM_S > 0$ og $\max(T_A,T_F) < D$

# %%
L = 80.0
B = 18.0
D = 10.0
T = 3.20
KG = 3.80
rho = 1.025
LCG = 40.0
N = 5
x_damage_start = 16.0
x_damage_end = 32.0

nabla = None
Delta = None
l_d = None
T_S = None
LCB_S = None
LCF_S = None
I_WL_S = None
I_F_S = None
BM_T_S = None
BM_L_S = None
GM_S = None
M_T = None
trim_cm = None
t_a_cm = None
t_f_cm = None
T_A = None
T_F = None
T_crit = None
